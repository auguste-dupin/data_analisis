# %%
# Config
# Tables
import pandas as pd
import pyreadstat
# Charting
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots
# Math
import numpy as np
# Tools
import os

import plotly.io as pio
pio.renderers.default = "notebook_connected"

# %%
df_original = pd.read_excel('./data/trademap/Trademap data.xlsx')
df_original
# Out:
#              Pais                           Region      Fecha      FOB  \
# 0     Philippines      Asia oriental y el Pacifico 2021-05-01  3032000
# 1        Viet Nam      Asia oriental y el Pacifico 2021-11-01  2807000
# 2        Viet Nam      Asia oriental y el Pacifico 2021-09-01  2716000
# 3     Philippines      Asia oriental y el Pacifico 2021-08-01  3506000
# 4     Philippines      Asia oriental y el Pacifico 2021-09-01  3133000
# ...           ...                              ...        ...      ...
# 1051      Algeria  Oriente Medio y Norte de Africa 2021-06-01        0
# 1052      Algeria  Oriente Medio y Norte de Africa 2021-07-01        0
# 1053      Algeria  Oriente Medio y Norte de Africa 2021-08-01        0
# 1054      Algeria  Oriente Medio y Norte de Africa 2021-10-01        0
# 1055      Algeria  Oriente Medio y Norte de Africa 2021-11-01        0
#
#           Kg    Precio
# 0     561236  5.402362
# 1     507178  5.534546
# 2     494250  5.495195
# 3     491297  7.136213
# 4     446619  7.014928
# ...      ...       ...
# 1051       0       NaN
# 1052       0       NaN
# 1053       0       NaN
# 1054       0       NaN
# 1055       0       NaN
#
# [1056 rows x 6 columns]

# %%
def clean(df_original):
    df = df_original.copy()

    # Fecha -> Datetime
    df['Fecha'] = pd.to_datetime(df['Fecha'])

    # Drop NA and Sort
    df = df.dropna().sort_values(by=['Kg', 'Pais'], ascending=False)

    return df

df = clean(df_original)
df
# Out:
#                          Pais                       Region      Fecha  \
# 0                 Philippines  Asia oriental y el Pacifico 2021-05-01
# 1                    Viet Nam  Asia oriental y el Pacifico 2021-11-01
# 2                    Viet Nam  Asia oriental y el Pacifico 2021-09-01
# 3                 Philippines  Asia oriental y el Pacifico 2021-08-01
# 4                 Philippines  Asia oriental y el Pacifico 2021-09-01
# ..                        ...                          ...        ...
# 356                   Belgium        Europa y Asia central 2020-12-01
# 357                   Belgium        Europa y Asia central 2021-02-01
# 358            United Kingdom        Europa y Asia central 2021-01-01
# 359                   Belgium        Europa y Asia central 2021-09-01
# 360  United States of America            America del Norte 2021-09-01
#
#          FOB      Kg     Precio
# 0    3032000  561236   5.402362
# 1    2807000  507178   5.534546
# 2    2716000  494250   5.495195
# 3    3506000  491297   7.136213
# 4    3133000  446619   7.014928
# ..       ...     ...        ...
# 356     1000      13  76.923077
# 357        0       7   0.000000
# 358        0       2   0.000000
# 359        0       2   0.000000
# 360        0       1   0.000000
#
# [361 rows x 6 columns]

# %%
def average(df):
    avg_df = pd.DataFrame(columns=['Precio'])

    for month in df.Fecha.unique():
        temp_df = df.copy()[df['Fecha'] == month]
        avg = np.average(temp_df.Precio, weights=temp_df.Kg)
        # print(avg)
        avg_df.loc[month] = avg
        avg_df = avg_df.sort_index()

    return avg_df

avg_df = average(df)
avg_df
# Out:
#               Precio
# 2020-12-01  2.485659
# 2021-01-01  1.121749
# 2021-02-01  1.993563
# 2021-03-01  2.121645
# 2021-04-01  1.971259
# 2021-05-01  3.143178
# 2021-06-01  2.981528
# 2021-07-01  2.725310
# 2021-08-01  3.556559
# 2021-09-01  3.763834
# 2021-10-01  4.090622
# 2021-11-01  3.026077

# %%
def sum_Kg_df(df, n_countries=10):
    df = df.copy()

    df = df.groupby(by=['Pais']).sum().sort_values(by=['Kg'], ascending=False)

    top = df[0:n_countries]
    bottom = df[n_countries:].sum()
    bottom.name = 'OTHER'

    top.loc['other'] = bottom

    normalized_sum = df['Kg']
    normalized_sum = (normalized_sum-normalized_sum.min())/(normalized_sum.max()-normalized_sum.min())
    
    return top['Kg'], df, normalized_sum

top_countries, full_sum, normalized_sum = sum_Kg_df(df, n_countries=10)
normalized_sum
# Out:
# C:\Users\Dasa\AppData\Local\Temp\ipykernel_3364\1639839836.py:10: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Pais
# Viet Nam                            1.000000
# Mexico                              0.622932
# Philippines                         0.603283
# Chile                               0.373700
# Saudi Arabia                        0.311300
#                                       ...
# Madagascar                          0.000429
# Lao People's Democratic Republic    0.000403
# Bulgaria                            0.000246
# Vanuatu                             0.000152
# Dominican Republic                  0.000000
# Name: Kg, Length: 88, dtype: float64

# %%
def get_df_for_top_countries(df, top_countries):
    df = df.copy()
    countries = top_countries.index.values

    df = df[df['Pais'].isin(countries)]
    df = df.dropna()

    return df

df_top = get_df_for_top_countries(df, top_countries)
df_top
# Out:
#             Pais                           Region      Fecha      FOB      Kg  \
# 0    Philippines      Asia oriental y el Pacifico 2021-05-01  3032000  561236
# 1       Viet Nam      Asia oriental y el Pacifico 2021-11-01  2807000  507178
# 2       Viet Nam      Asia oriental y el Pacifico 2021-09-01  2716000  494250
# 3    Philippines      Asia oriental y el Pacifico 2021-08-01  3506000  491297
# 4    Philippines      Asia oriental y el Pacifico 2021-09-01  3133000  446619
# ..           ...                              ...        ...      ...     ...
# 279  Philippines      Asia oriental y el Pacifico 2021-02-01    64000    4698
# 280   Bangladesh                  Asia meridional 2020-12-01    10000    4694
# 296     Thailand      Asia oriental y el Pacifico 2021-04-01     7000    2981
# 307     Thailand      Asia oriental y el Pacifico 2021-02-01     5000    2006
# 308        Egypt  Oriente Medio y Norte de Africa 2021-04-01     1000    2000
#
#         Precio
# 0     5.402362
# 1     5.534546
# 2     5.495195
# 3     7.136213
# 4     7.014928
# ..         ...
# 279  13.622818
# 280   2.130379
# 296   2.348205
# 307   2.492522
# 308   0.500000
#
# [106 rows x 6 columns]

# %%
fig = px.treemap(
    df,
    path=['Region','Pais'],
    values='Kg',
    color='Precio',
    # hover_data=['Precio'],
    names = 'Pais',
    # parents = 'Region',
    color_continuous_scale=['green','yellow','red'],
    # color_continuous_midpoint=np.average(df['Precio'], weights=df['Kg']),
    range_color=[0,5],
    # col
    title='Treemap Region-Pais de los Kilogramos exportados por China y su Precio'
    )
fig.update_layout(margin = dict(t=50, l=25, r=25, b=25))
fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="0117ff03-5a24-4e2e-8caa-ff7e9792a30e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0117ff03-5a24-4e2e-8caa-ff7e9792a30e")) {                    Plotly.newPlot(                        "0117ff03-5a24-4e2e-8caa-ff7e9792a30e",                        [{"branchvalues":"total","customdata":[[5.0626075804110835],[1.317908917850344],[1.2571428571428571],[1.1538461538461537],[1.5240174370807398],[1.3275804845668768],[0.6666666666666666],[1.8808195109869272],[0.9871668311944719],[0.8604206500956023],[4.506113342694568],[1.3529411764705883],[6.272157076629397],[1.0892611863355952],[1.3973879780889564],[1.1878453038674033],[1.0845986984815619],[1.0076130765785938],[1.0047221943132725],[8.181818181818182],[18.51851851851852],[3.5035035035035036],[4.321285254455993],[1.2884753042233357],[0.1834862385321101],[0.9714285714285714],[3.4801845307146517],[6.721527734154155],[1.1916861669857628],[1.310483870967742],[1.0655737704918034],[8.370895041854475],[2.311873229732833],[7.635488876543176],[3.41649679882863],[12.023809523809524],[0.612358842281577],[7.440811724915445],[1.5441000292846556],[5.495799638847452],[1.488833746898263],[1.6422960485961338],[3.8274783974128304],[0.9211612985197891],[0.6134969325153374],[5.35508320975449],[0.864688956899728],[1.1560693641618498],[3.0814420705517223],[1.40021773858465],[1.0291006803498943],[1.0038610038610039],[1.0638297872340425],[2.899391127863149],[0.6065857885615251],[3.276801133596068],[1.8313043881710291],[7.222222222222222],[1.5414352474859925],[1.0552001582800237],[1.1380679311865902],[5.7828611391901195],[1.1363636363636365],[1.8581050901359633],[6.784768795095509],[0.89396100808369],[1.8561221603057956],[2.5241193628000897],[1.0],[4.984121383203952],[1.4157621519584709],[3.933947640761211],[1.883357219583496],[0.425531914893617],[5.0],[1.7295452663583444],[0.8],[0.831946755407654],[0.8076923076923077],[3.4234507663539864],[7.30528603004533],[1.143719834389368],[1.1569204880100967],[3.0864197530864197],[3.646442305796801],[3.000230786983614],[0.9696969696969697],[0.6435006435006435],[1.4985845875996209],[1.3029080984692254],[1.5406044234340706],[2.2677291465075577],[3.8898720761708505],[4.554986222394242],[5.357845064883995],[2.8453465765879087]],"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"labels=%{label}<br>Kg=%{value}<br>parent=%{parent}<br>id=%{id}<br>Precio=%{color}<extra></extra>","ids":["Oriente Medio y Norte de Africa/Algeria","America Latina/Argentina","Asia oriental y el Pacifico/Australia","Oriente Medio y Norte de Africa/Bahrain","Asia meridional/Bangladesh","Europa y Asia central/Belgium","Africa subsahariana/Benin","America Latina/Brazil","Europa y Asia central/Bulgaria","Africa subsahariana/Cabo Verde","Asia oriental y el Pacifico/Cambodia","Africa subsahariana/Cameroon","America del Norte/Canada","America Latina/Chile","America Latina/Colombia","Africa subsahariana/Congo, Democratic Republic of the","Europa y Asia central/Croatia","Europa y Asia central/Cyprus","Africa subsahariana/C\u00f4te d'Ivoire","Oriente Medio y Norte de Africa/Djibouti","Gran Caribe/Dominican Republic","America Latina/Ecuador","Oriente Medio y Norte de Africa/Egypt","Gran Caribe/El Salvador","Africa subsahariana/Equatorial Guinea","Africa subsahariana/Ethiopia","Asia oriental y el Pacifico/Fiji","Europa y Asia central/Germany","Africa subsahariana/Ghana","Europa y Asia central/Greece","Africa subsahariana/Guinea","Asia oriental y el Pacifico/Hong Kong, China","Asia meridional/India","Asia oriental y el Pacifico/Indonesia","Oriente Medio y Norte de Africa/Iran, Islamic Republic of","Oriente Medio y Norte de Africa/Israel","Europa y Asia central/Italy","Gran Caribe/Jamaica","Asia oriental y el Pacifico/Japan","Oriente  ...

# %%
fig = px.bar(
    df[df['Region'].isin(['Asia oriental y el Pacifico', 'America Latina'])],
    # df,
    x='Fecha',
    y='Kg',
    color='Precio',
    facet_col = 'Region',
    range_color = [0,5],
    color_continuous_scale=['green','grey','red'],
    hover_data=['Pais'],
    # name='Pais',
    title='Volumen Exportado de China por Region y precio (color)',
)
fig.update_layout(
    height = 800
)
fig.show()
# Out:
# <div>                            <div id="33594781-763e-4edd-862d-1c46447a5a0f" class="plotly-graph-div" style="height:800px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("33594781-763e-4edd-862d-1c46447a5a0f")) {                    Plotly.newPlot(                        "33594781-763e-4edd-862d-1c46447a5a0f",                        [{"alignmentgroup":"True","customdata":[["Philippines"],["Viet Nam"],["Viet Nam"],["Philippines"],["Philippines"],["Viet Nam"],["Viet Nam"],["Viet Nam"],["Viet Nam"],["Thailand"],["Viet Nam"],["Viet Nam"],["Viet Nam"],["Philippines"],["Viet Nam"],["Thailand"],["Viet Nam"],["Philippines"],["Philippines"],["Korea, Republic of"],["Thailand"],["Thailand"],["Korea, Republic of"],["Korea, Republic of"],["Korea, Republic of"],["Philippines"],["Macao, China"],["Macao, China"],["Viet Nam"],["Taipei, Chinese"],["Korea, Republic of"],["Malaysia"],["Thailand"],["Philippines"],["Korea, Republic of"],["Indonesia"],["Indonesia"],["Korea, Republic of"],["Macao, China"],["Philippines"],["Malaysia"],["Taipei, Chinese"],["Cambodia"],["Indonesia"],["Taipei, Chinese"],["Macao, China"],["Indonesia"],["Thailand"],["Thailand"],["Taipei, Chinese"],["Malaysia"],["Japan"],["Macao, China"],["Indonesia"],["Taipei, Chinese"],["Indonesia"],["Malaysia"],["Korea, Republic of"],["Fiji"],["Korea, Republic of"],["Australia"],["Cambodia"],["Macao, China"],["Malaysia"],["Taipei, Chinese"],["Malaysia"],["Thailand"],["Cambodia"],["Thailand"],["Japan"],["Thailand"],["Philippines"],["Macao, China"],["Myanmar"],["Singapore"],["Korea, Republic of"],["Korea, Republic of"],["Cambodia"],["Australia"],["Cambodia"],["Hong Kong, China"],["Japan"],["Hong Kong, China"],["Macao, China"],["Malaysia"],["Hong Kong, China"],["Malaysia"],["Philippines"],["Myanmar"],["Malaysia"],["Cambodia"],["Cambodia"],["Macao, China"],["Malaysia"],["Japan"],["Singapore"],["Philippines"],["Myanmar"],["Indonesia"],["Japan"],["Malaysia"],["Indonesia"],["Hong Kong, China"],["Thailand"],["Thailand"],["Singapore"],["Taipei, Chinese"],["Lao People's Democratic Republic"],["Malaysia"],["Cambodia"],["Indonesia"],["Hong Kong, China"],["Hong Kong, China"],["Singapore"],["Singapore"],["Macao, China"],["Vanuatu"],["Hong Kong, China"],["Japan"],["Japan"],["Japan"],["Singapore"]],"hovertemplate":"Region=Asia oriental y el Pacifico<br>Fecha=%{x}<br>Kg=%{y}<br>Pais=%{customdata[0]}<br>Precio=%{marker.color}<extra></extra>","legendgroup":"","marker":{"color":[5.4023619297407866,5.534546056808458,5.495194739504299,7.136212922122463,7.014927712434984,4.045311211823394,1.6582652970529603,7.025344346391567,1.1906742192766655,2.364833224067112,2.560108364375212,1.8570920123900105,4.1984481128964894,5.976404270546657,2.2245975805529152,0.8216644081650212,1.9152449091909742,3.7176938369781314,4.36871996505024,5.608322665968868,1.1028775733810046,2.113140396730193,5.2741501629379215,2.9379082766516262,2.1609117074789066,2.0480871818320376,0.3804432651787108,1.0020449897750512,0.9644091967702552,1.838254278072105,3.0680984459414393,1.4253428527402536,1.9853612695723533,5.636178644104102,3.498776119815796,7.599141809121739,8.378532686268912,2.7585017887160035,0.9935634368655234,2.0339501452821533,3.9687442090308234,1.6968677999875459,3.1376834217920697,7.563869185864038,2.1418835594210424,1.0066569248254587,7.569150774192487,1.3182130087760482,3.376310175308413,1.6070322180916976,1.7745179226310186,1.3194722111155537,0.7870101897108773,7.312121965365813,2.1055554270112684,7.816223429606329,1.853010540501516,4.31077694235589,3.4801845307146517,2.572100913916708,1.4620689655172414,1.2266859962641836,0.9981851179673321,6.182380216383308,2.092514504930091,6.600873645041255,1.507010876687197,4.785629998688869,1.7137096774193548,2.0415801830616895,0.9750661652040674,10.485844110450891,1.31916452913155,4.52539456 ...

# %%
# Create figure with secondary y-axis
fig = make_subplots(specs=[[{"secondary_y": True}]])

# Add traces
for pais in df['Pais'].unique():
    pais_df = df[df.Pais == pais].sort_values(by=['Fecha'])
    fig.add_trace(
        go.Bar(
            x=pais_df.Fecha,
            y=pais_df.Kg,
            name=pais,
            # mode='lines',
            ),
        secondary_y=False,
    )

fig.add_trace(
    go.Scatter(x=avg_df.index, y=avg_df['Precio'], name="Precio Promedio Global"),
    secondary_y=True,
)

# Add figure title
fig.update_layout(
    title_text="Double Y Axis Example"
)

# Set x-axis title
fig.update_xaxes(title_text="xaxis title")

# Set y-axes titles
fig.update_yaxes(title_text="<b>primary</b> yaxis title", secondary_y=False)
fig.update_yaxes(title_text="<b>secondary</b> yaxis title", secondary_y=True)

fig.show()
# Out:
# <div>                            <div id="5dae991c-3dd3-4014-a289-0a46582ce401" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5dae991c-3dd3-4014-a289-0a46582ce401")) {                    Plotly.newPlot(                        "5dae991c-3dd3-4014-a289-0a46582ce401",                        [{"name":"Philippines","x":["2020-12-01T00:00:00","2021-01-01T00:00:00","2021-02-01T00:00:00","2021-03-01T00:00:00","2021-04-01T00:00:00","2021-05-01T00:00:00","2021-06-01T00:00:00","2021-07-01T00:00:00","2021-08-01T00:00:00","2021-09-01T00:00:00","2021-10-01T00:00:00","2021-11-01T00:00:00"],"y":[150900.0,104976.0,4698.0,74696.0,15040.0,561236.0,271066.0,141918.0,491297.0,446619.0,65390.0,28610.0],"type":"bar","xaxis":"x","yaxis":"y"},{"name":"Viet Nam","x":["2020-12-01T00:00:00","2021-01-01T00:00:00","2021-02-01T00:00:00","2021-03-01T00:00:00","2021-04-01T00:00:00","2021-05-01T00:00:00","2021-06-01T00:00:00","2021-07-01T00:00:00","2021-08-01T00:00:00","2021-09-01T00:00:00","2021-10-01T00:00:00","2021-11-01T00:00:00"],"y":[181700.0,342663.0,97469.0,393785.0,283777.0,295300.0,253529.0,429386.0,272958.0,494250.0,354004.0,507178.0],"type":"bar","xaxis":"x","yaxis":"y"},{"name":"Mexico","x":["2020-12-01T00:00:00","2021-01-01T00:00:00","2021-02-01T00:00:00","2021-03-01T00:00:00","2021-04-01T00:00:00","2021-05-01T00:00:00","2021-06-01T00:00:00","2021-07-01T00:00:00","2021-08-01T00:00:00","2021-09-01T00:00:00","2021-10-01T00:00:00","2021-11-01T00:00:00"],"y":[157780.0,216624.0,225989.0,157600.0,126235.0,120307.0,294743.0,216745.0,187965.0,222481.0,62698.0,444026.0],"type":"bar","xaxis":"x","yaxis":"y"},{"name":"Chile","x":["2021-01-01T00:00:00","2021-02-01T00:00:00","2021-04-01T00:00:00","2021-06-01T00:00:00","2021-07-01T00:00:00","2021-09-01T00:00:00","2021-10-01T00:00:00","2021-11-01T00:00:00"],"y":[345447.0,238389.0,236866.0,131368.0,34113.0,324985.0,49122.0,99415.0],"type":"bar","xaxis":"x","yaxis":"y"},{"name":"Rwanda","x":["2021-09-01T00:00:00"],"y":[315450.0],"type":"bar","xaxis":"x","yaxis":"y"},{"name":"Thailand","x":["2020-12-01T00:00:00","2021-01-01T00:00:00","2021-02-01T00:00:00","2021-03-01T00:00:00","2021-04-01T00:00:00","2021-05-01T00:00:00","2021-06-01T00:00:00","2021-07-01T00:00:00","2021-08-01T00:00:00","2021-09-01T00:00:00","2021-10-01T00:00:00","2021-11-01T00:00:00"],"y":[29760.0,55378.0,2006.0,232455.0,2981.0,125879.0,28716.0,75553.0,298964.0,138728.0,30524.0,53905.0],"type":"bar","xaxis":"x","yaxis":"y"},{"name":"Bangladesh","x":["2020-12-01T00:00:00","2021-01-01T00:00:00","2021-02-01T00:00:00","2021-03-01T00:00:00","2021-04-01T00:00:00","2021-06-01T00:00:00","2021-07-01T00:00:00","2021-09-01T00:00:00","2021-11-01T00:00:00"],"y":[4694.0,31868.0,37305.0,21460.0,49623.0,51603.0,108003.0,236623.0,182566.0],"type":"bar","xaxis":"x","yaxis":"y"},{"name":"Nigeria","x":["2021-01-01T00:00:00","2021-02-01T00:00:00","2021-04-01T00:00:00","2021-05-01T00:00:00","2021-06-01T00:00:00","2021-07-01T00:00:00","2021-08-01T00:00:00","2021-09-01T00:00:00","2021-11-01T00:00:00"],"y":[215080.0,164520.0,46373.0,122186.0,98265.0,20000.0,16700.0,27687.0,22000.0],"type":"bar","xaxis":"x","yaxis":"y"},{"name":"Saudi Arabia","x":["2020-12-01T00:00:00","2021-01-01T00:00:00","2021-03-01T00:00:00","2021-04-01T00:00:00","2021-05-01T00:00:00","2021-06-01T00:00:00","2021-07-01T00:00:00","2021-08-01T00:00:00","2021-09-01T00:00:00","2021-10-01T00:00:00","2021-11-01T00:00:00"],"y":[209258.0,78386.0,130000.0,115810.0,52474.0,108761.0,182287.0,104000.0,52000.0,104000.0,79000.0],"type":"bar","xaxis":"x","yaxis":"y"},{"name":"Ghana","x":["2021-01-01T00:00:00","2021-04-01T00:00:00","2021-05-01T00:00:00","2021-06-01T00:00:00","2021-08-01T00:00:00","2021-09-01T00:00:00","2021-10-01T00:00:00","2021-11-01T00:00:00"],"y":[15270.0,4230.0,1 ...

# %%
normalized_full = full['Kg']
# normalized_full=(normalized_full-normalized_full.mean())/normalized_full.std()
normalized_full = (normalized_full-normalized_full.min())/(normalized_full.max()-normalized_full.min())
normalized_full
# Out:
# Pais
# Viet Nam                            1.000000
# Mexico                              0.622932
# Philippines                         0.603283
# Chile                               0.373700
# Saudi Arabia                        0.311300
#                                       ...
# Madagascar                          0.000429
# Lao People's Democratic Republic    0.000403
# Bulgaria                            0.000246
# Vanuatu                             0.000152
# Dominican Republic                  0.000000
# Name: Kg, Length: 88, dtype: float64

# %%
fig = px.line(
    df,
    x = df.Fecha,
    y = 'Precio',
    color = 'Pais',
    # opacity = normalized_full
)

fig.show()
# Out:
# <div>                            <div id="80968b0e-d7ce-4312-a815-9acccd01334b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("80968b0e-d7ce-4312-a815-9acccd01334b")) {                    Plotly.newPlot(                        "80968b0e-d7ce-4312-a815-9acccd01334b",                        [{"hovertemplate":"Pais=Philippines<br>Fecha=%{x}<br>Precio=%{y}<extra></extra>","legendgroup":"Philippines","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Philippines","orientation":"v","showlegend":true,"x":["2021-05-01T00:00:00","2021-08-01T00:00:00","2021-09-01T00:00:00","2021-06-01T00:00:00","2020-12-01T00:00:00","2021-07-01T00:00:00","2021-01-01T00:00:00","2021-03-01T00:00:00","2021-10-01T00:00:00","2021-11-01T00:00:00","2021-04-01T00:00:00","2021-02-01T00:00:00"],"xaxis":"x","y":[5.4,7.14,7.01,5.98,3.72,4.37,2.05,5.64,2.03,10.49,1.46,13.62],"yaxis":"y","type":"scatter"},{"hovertemplate":"Pais=Viet Nam<br>Fecha=%{x}<br>Precio=%{y}<extra></extra>","legendgroup":"Viet Nam","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Viet Nam","orientation":"v","showlegend":true,"x":["2021-11-01T00:00:00","2021-09-01T00:00:00","2021-07-01T00:00:00","2021-03-01T00:00:00","2021-10-01T00:00:00","2021-01-01T00:00:00","2021-05-01T00:00:00","2021-04-01T00:00:00","2021-08-01T00:00:00","2021-06-01T00:00:00","2020-12-01T00:00:00","2021-02-01T00:00:00"],"xaxis":"x","y":[5.53,5.5,4.05,1.66,7.03,1.19,2.56,1.86,4.2,2.22,1.92,0.96],"yaxis":"y","type":"scatter"},{"hovertemplate":"Pais=Mexico<br>Fecha=%{x}<br>Precio=%{y}<extra></extra>","legendgroup":"Mexico","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Mexico","orientation":"v","showlegend":true,"x":["2021-11-01T00:00:00","2021-06-01T00:00:00","2021-02-01T00:00:00","2021-09-01T00:00:00","2021-07-01T00:00:00","2021-01-01T00:00:00","2021-08-01T00:00:00","2020-12-01T00:00:00","2021-03-01T00:00:00","2021-04-01T00:00:00","2021-05-01T00:00:00","2021-10-01T00:00:00"],"xaxis":"x","y":[1.16,1.52,1.34,1.65,1.51,1.26,1.62,1.27,1.37,1.39,1.53,1.48],"yaxis":"y","type":"scatter"},{"hovertemplate":"Pais=Chile<br>Fecha=%{x}<br>Precio=%{y}<extra></extra>","legendgroup":"Chile","line":{"color":"#ab63fa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Chile","orientation":"v","showlegend":true,"x":["2021-01-01T00:00:00","2021-09-01T00:00:00","2021-02-01T00:00:00","2021-04-01T00:00:00","2021-06-01T00:00:00","2021-11-01T00:00:00","2021-10-01T00:00:00","2021-07-01T00:00:00"],"xaxis":"x","y":[0.91,1.19,0.92,1.19,1.18,1.4,1.1,1.2],"yaxis":"y","type":"scatter"},{"hovertemplate":"Pais=Rwanda<br>Fecha=%{x}<br>Precio=%{y}<extra></extra>","legendgroup":"Rwanda","line":{"color":"#FFA15A","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Rwanda","orientation":"v","showlegend":true,"x":["2021-09-01T00:00:00"],"xaxis":"x","y":[0.89],"yaxis":"y","type":"scatter"},{"hovertemplate":"Pais=Thailand<br>Fecha=%{x}<br>Precio=%{y}<extra></extra>","legendgroup":"Thailand","line":{"color":"#19d3f3","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Thailand","orientation":"v","showlegend":true,"x":["2021-08-01T00:00:00","2021-03-01T00:00:00","2021-09-01T00:00:00","2021-05-01T00:00:00","2021-07-01T00:00:00","2021-01-01T00:00:00","2021-11-01T00:00:00","2021-10-01T00:00:00","2020-12-01T00:00:00","2021-06-01T00:00:00","2021-04-01T00:00:00","2021-02-01T00:00:00"],"xaxis":"x","y":[2.36,0.82,1.1,2.11,1.99,1.32,3.38,1.51,1.71,0.98,2.35,2.49],"yaxis":"y","type":"scatter"},{"hovertemplate":"Pais=Bangladesh<br>Fecha=%{x}<br>Precio=%{y}<extra></extra>","legendgroup":"Bangladesh","line":{"color":"#FF6692","dash":"solid"},"marker":{"symbol":"cir ...

# %%
df.Fecha.unique()
# Out:
# array(['2021-05-01T00:00:00.000000000', '2021-11-01T00:00:00.000000000',
#        '2021-09-01T00:00:00.000000000', '2021-08-01T00:00:00.000000000',
#        '2021-07-01T00:00:00.000000000', '2021-03-01T00:00:00.000000000',
#        '2021-10-01T00:00:00.000000000', '2021-01-01T00:00:00.000000000',
#        '2021-06-01T00:00:00.000000000', '2021-04-01T00:00:00.000000000',
#        '2021-02-01T00:00:00.000000000', '2020-12-01T00:00:00.000000000'],
#       dtype='datetime64[ns]')

# %%
avg_df = pd.DataFrame(columns=['Precio'])

for month in df.Fecha.unique():
    temp_df = df.copy()[df['Fecha'] == month]
    avg = np.average(temp_df.Precio, weights=temp_df.Kg)
    # print(avg)
    avg_df.loc[month] = avg
    avg_df = avg_df.sort_index()

avg_df
# Out:
#               Precio
# 2020-12-01  2.485628
# 2021-01-01  1.121008
# 2021-02-01  1.992638
# 2021-03-01  2.121146
# 2021-04-01  1.972524
# 2021-05-01  3.142066
# 2021-06-01  2.982081
# 2021-07-01  2.727451
# 2021-08-01  3.556833
# 2021-09-01  3.764178
# 2021-10-01  4.092415
# 2021-11-01  3.026170

# %%
fig = go.Figure()

# Add scatter trace with medium sized markers
fig.add_trace(
    go.Scatter(
        mode='markers',
        x=x,
        y=y,
        marker=dict(
            color='LightSkyBlue',
            size=20,
            line=dict(
                color='MediumPurple',
                width=2
            )
        ),
        showlegend=False
    )
)

# Add trace with large marker
fig.add_trace(
    go.Scatter(
        mode='markers',
        x=[2],
        y=[4.5],
        marker=dict(
            color='LightSkyBlue',
            size=120,
            line=dict(
                color='MediumPurple',
                width=12
            )
        ),
        showlegend=False
    )
)

fig.show()
