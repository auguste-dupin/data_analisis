# %%
# Config
# Tables
import pandas as pd
import pyreadstat
# Charting
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots
# Math
import numpy as np
# Tools
import os

import plotly.io as pio
pio.renderers.default = "notebook_connected"

# %%
path = './data/USITC/'

archivos = os.listdir(path)
df_original = pd.DataFrame()

for archivo in archivos:
    archivo_df = pd.read_csv(path + archivo)
    df_original = pd.concat([df_original, archivo_df])

df_original
# Out:
#           Fecha     Partida  \
# 0      20220201  7318.19.00
# 1      20220201  7318.16.00
# 2      20220201  7307.92.90
# 3      20220101  7318.22.00
# 4      20220101  7315.11.00
# ...         ...         ...
# 12850  20200801  7326.90.86
# 12851  20200901  7326.90.86
# 12852  20201001  7326.90.86
# 12853  20201101  7326.90.86
# 12854  20201201  7326.90.86
#
#                                              Descripcion            Pais  \
# 0      Iron or steel, threaded articles similar to sc...         Finland
# 1                                    Iron or steel, nuts         Germany
# 2      Iron or steel (o/than stainless), not cast, th...           Italy
# 3      Iron or steel, washers (o/than spring washers ...  United Kingdom
# 4                            Iron or steel, roller chain          Taiwan
# ...                                                  ...             ...
# 12850                     Iron or steel, articles, nesoi         Vietnam
# 12851                     Iron or steel, articles, nesoi         Vietnam
# 12852                     Iron or steel, articles, nesoi         Vietnam
# 12853                     Iron or steel, articles, nesoi         Vietnam
# 12854                     Iron or steel, articles, nesoi         Vietnam
#
#                             Region     Unidad Cantidad     FOB
# 0            Europa y Asia central  kilograms       21   2,117
# 1            Europa y Asia central  kilograms       22   2,154
# 2            Europa y Asia central  kilograms      191   2,173
# 3            Europa y Asia central  kilograms        1   2,380
# 4      Asia oriental y el Pacifico  kilograms      238   2,149
# ...                            ...        ...      ...     ...
# 12850  Asia oriental y el Pacifico  kilograms        0       0
# 12851  Asia oriental y el Pacifico  kilograms    1,186  18,275
# 12852  Asia oriental y el Pacifico  kilograms        0       0
# 12853  Asia oriental y el Pacifico  kilograms        0       0
# 12854  Asia oriental y el Pacifico  kilograms      678  10,443
#
# [15165 rows x 8 columns]

# %%
def clean(df_original):
    df = df_original.copy()

    # Eliminar Comas (,)
    # df = df.replace(',','')

    # Configurar Formato
    ## Fecha -> Datetime
    df['Fecha'] = pd.to_datetime(df['Fecha'], format='%Y%m%d')
    ## Cantidad -> Float
    df["Cantidad"] = df["Cantidad"].str.replace(",","").astype(float)
    ## FOB -> Float
    df["FOB"] = df["FOB"].str.replace(",","").astype(float)


    # Crear variable Precio
    df['Precio'] = df['FOB'] / df['Cantidad']
    df['HS2'] = df['Partida'].str[:2]
    df['HS4'] = df['Partida'].str[:4]
    
    # Drop NA and Sort
    df = df[df['Precio'] != np.Infinity]
    df = df.dropna().sort_values(by=['Cantidad', 'Pais'], ascending=False)

    return df

df_total = clean(df_original)
df_total
# Out:
#            Fecha     Partida  \
# 6417  2020-07-01  7214.20.00
# 12309 2020-07-01  7326.20.00
# 6419  2020-09-01  7214.20.00
# 600   2021-10-01  7214.20.00
# 6420  2020-10-01  7214.20.00
# ...          ...         ...
# 9026  2020-12-01  7309.00.00
# 9     2021-01-01  7204.29.00
# 5301  2020-07-01  7204.29.00
# 3823  2021-08-01  7318.15.80
# 8     2021-12-01  7309.00.00
#
#                                              Descripcion           Pais  \
# 6417   Iron/nonalloy steel, concrete reinforcing bars...  Dominican Rep
# 12309             Iron or steel, articles of wire, nesoi          China
# 6419   Iron/nonalloy steel, concrete reinforcing bars...  Dominican Rep
# 600    Iron/nonalloy steel, concrete reinforcing bars...         Turkey
# 6420   Iron/nonalloy steel, concrete reinforcing bars...  Dominican Rep
# ...                                                  ...            ...
# 9026   Iron/steel, reservoirs, tanks, vats, siml. con...         Canada
# 9         Alloy steel (o/than stainless) waste and scrap  Br  Virgin Is
# 5301      Alloy steel (o/than stainless) waste and scrap  Br  Virgin Is
# 3823   Iron or steel, screws and bolts, nesoi, having...        Belgium
# 8      Iron/steel, reservoirs, tanks, vats, siml. con...      Australia
#
#                             Region       Unidad   Cantidad        FOB  \
# 6417                   Gran Caribe    kilograms  8107590.0  3817010.0
# 12309  Asia oriental y el Pacifico       number  7232480.0    43895.0
# 6419                   Gran Caribe    kilograms  6878665.0  3130017.0
# 600          Europa y Asia central    kilograms  5915815.0  4365484.0
# 6420                   Gran Caribe    kilograms  5779984.0  2734497.0
# ...                            ...          ...        ...        ...
# 9026             America del Norte       number        1.0     9195.0
# 9                      Gran Caribe  metric tons        1.0     2375.0
# 5301                   Gran Caribe  metric tons        1.0     3200.0
# 3823         Europa y Asia central    kilograms        1.0     3288.0
# 8      Asia oriental y el Pacifico       number        1.0    29444.0
#
#              Precio HS2   HS4
# 6417       0.470795  72  7214
# 12309      0.006069  73  7326
# 6419       0.455033  72  7214
# 600        0.737935  72  7214
# 6420       0.473098  72  7214
# ...             ...  ..   ...
# 9026    9195.000000  73  7309
# 9       2375.000000  72  7204
# 5301    3200.000000  72  7204
# 3823    3288.000000  73  7318
# 8      29444.000000  73  7309
#
# [4516 rows x 11 columns]

# %%
def unidades(df):
    df = df.copy()
    df = df.groupby(by=['Unidad', 'HS2']).sum().reset_index()
    
    fig = px.sunburst(
        df,
        values='FOB',
        path = ['Unidad','HS2']
    )
    fig.show()
unidades(df_total)
# Out:
# <div>                            <div id="56a8a7eb-601b-48fb-8eed-83bfe8465638" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("56a8a7eb-601b-48fb-8eed-83bfe8465638")) {                    Plotly.newPlot(                        "56a8a7eb-601b-48fb-8eed-83bfe8465638",                        [{"branchvalues":"total","domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"labels=%{label}<br>FOB=%{value}<br>parent=%{parent}<br>id=%{id}<extra></extra>","ids":["kilograms/72","metric tons/72","gross/73","kilograms/73","number/73","square meters/73","thousand units/73","gross","kilograms","metric tons","number","square meters","thousand units"],"labels":["72","72","73","73","73","73","73","gross","kilograms","metric tons","number","square meters","thousand units"],"name":"","parents":["kilograms","metric tons","gross","kilograms","number","square meters","thousand units","","","","","",""],"values":[247820828.0,220927.0,31369.0,127063551.0,73626565.0,2812647.0,18437.0,31369.0,374884379.0,220927.0,73626565.0,2812647.0,18437.0],"type":"sunburst"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl" ...

# %%
def solo_unidades(unidad, df):
    return df[df['Unidad'] == unidad]

df = solo_unidades('kilograms', df_total)
df
# Out:
#            Fecha     Partida  \
# 6417  2020-07-01  7214.20.00
# 6419  2020-09-01  7214.20.00
# 600   2021-10-01  7214.20.00
# 6420  2020-10-01  7214.20.00
# 6421  2020-11-01  7214.20.00
# ...          ...         ...
# 290   2021-12-01  7318.29.00
# 3542  2021-06-01  7317.00.65
# 10865 2020-03-01  7318.15.80
# 220   2021-12-01  7320.20.50
# 3823  2021-08-01  7318.15.80
#
#                                              Descripcion            Pais  \
# 6417   Iron/nonalloy steel, concrete reinforcing bars...   Dominican Rep
# 6419   Iron/nonalloy steel, concrete reinforcing bars...   Dominican Rep
# 600    Iron/nonalloy steel, concrete reinforcing bars...          Turkey
# 6420   Iron/nonalloy steel, concrete reinforcing bars...   Dominican Rep
# 6421   Iron/nonalloy steel, concrete reinforcing bars...   Dominican Rep
# ...                                                  ...             ...
# 290    Iron or steel, nonthreaded articles similar to...          France
# 3542   Iron or steel, nails, tacks, corrugated nails,...          France
# 10865  Iron or steel, screws and bolts, nesoi, having...          France
# 220    Iron or steel, helical springs (o/than suitabl...  Czech Republic
# 3823   Iron or steel, screws and bolts, nesoi, having...         Belgium
#
#                       Region     Unidad   Cantidad        FOB       Precio  \
# 6417             Gran Caribe  kilograms  8107590.0  3817010.0     0.470795
# 6419             Gran Caribe  kilograms  6878665.0  3130017.0     0.455033
# 600    Europa y Asia central  kilograms  5915815.0  4365484.0     0.737935
# 6420             Gran Caribe  kilograms  5779984.0  2734497.0     0.473098
# 6421             Gran Caribe  kilograms  5707382.0  2861072.0     0.501293
# ...                      ...        ...        ...        ...          ...
# 290    Europa y Asia central  kilograms        1.0     3170.0  3170.000000
# 3542   Europa y Asia central  kilograms        1.0     2157.0  2157.000000
# 10865  Europa y Asia central  kilograms        1.0     5124.0  5124.000000
# 220    Europa y Asia central  kilograms        1.0     2349.0  2349.000000
# 3823   Europa y Asia central  kilograms        1.0     3288.0  3288.000000
#
#       HS2   HS4
# 6417   72  7214
# 6419   72  7214
# 600    72  7214
# 6420   72  7214
# 6421   72  7214
# ...    ..   ...
# 290    73  7318
# 3542   73  7317
# 10865  73  7318
# 220    73  7320
# 3823   73  7318
#
# [3472 rows x 11 columns]

# %%
def average(df):
    avg_df = pd.DataFrame(columns=['Mes', 'Precio','HS2'])

    for month in df.Fecha.unique():
        temp_df = df.copy()[df['Fecha'] == month]
        for HS2 in df.HS2.unique():
            HS2_df = temp_df.copy()[temp_df['HS2'] == HS2]
            avg = np.average(HS2_df.Precio, weights=HS2_df.Cantidad)
            avg_df = pd.concat([avg_df, pd.DataFrame(data={
                'Mes': [month],
                'Precio': [avg],
                'HS2': [HS2]
            })], ignore_index=True)
    avg_df = avg_df.sort_values(by=['Mes'])
    # print(avg_df)

    # Grafica
    fig = px.line(
        avg_df,
        x='Mes',
        y='Precio',
        title='Precio Promedio x Fecha',
        color='HS2'
    )
    fig.show()

    return avg_df

avg_df = average(df)
# Out:
# <div>                            <div id="49cb063e-22cb-4572-82b0-ee78e6bf48a0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("49cb063e-22cb-4572-82b0-ee78e6bf48a0")) {                    Plotly.newPlot(                        "49cb063e-22cb-4572-82b0-ee78e6bf48a0",                        [{"hovertemplate":"HS2=73<br>Mes=%{x}<br>Precio=%{y}<extra></extra>","legendgroup":"73","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"73","orientation":"v","showlegend":true,"x":["2020-01-01T00:00:00","2020-02-01T00:00:00","2020-03-01T00:00:00","2020-04-01T00:00:00","2020-05-01T00:00:00","2020-06-01T00:00:00","2020-07-01T00:00:00","2020-08-01T00:00:00","2020-09-01T00:00:00","2020-10-01T00:00:00","2020-11-01T00:00:00","2020-12-01T00:00:00","2021-01-01T00:00:00","2021-02-01T00:00:00","2021-03-01T00:00:00","2021-04-01T00:00:00","2021-05-01T00:00:00","2021-06-01T00:00:00","2021-07-01T00:00:00","2021-08-01T00:00:00","2021-09-01T00:00:00","2021-10-01T00:00:00","2021-11-01T00:00:00","2021-12-01T00:00:00","2022-01-01T00:00:00","2022-02-01T00:00:00"],"xaxis":"x","y":[1.787107830337221,1.7601073271370111,1.5620368531974742,1.0974979087483892,1.2025593319169818,1.4093162366676415,1.3957969487942377,1.2622208181248906,1.2778672760661574,1.46144834135228,1.1814239531947521,1.6260700586378336,1.4696430963267049,1.3187834745995135,1.3751752396717942,1.682233647150212,1.2588102177917215,1.5198597077875404,1.5809869517938635,1.691387150840861,2.2765785110770285,1.7852274172547034,1.700955251684768,2.015594224051754,2.2005984592061605,1.927420089729647],"yaxis":"y","type":"scatter"},{"hovertemplate":"HS2=72<br>Mes=%{x}<br>Precio=%{y}<extra></extra>","legendgroup":"72","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"72","orientation":"v","showlegend":true,"x":["2020-01-01T00:00:00","2020-02-01T00:00:00","2020-03-01T00:00:00","2020-04-01T00:00:00","2020-05-01T00:00:00","2020-06-01T00:00:00","2020-07-01T00:00:00","2020-08-01T00:00:00","2020-09-01T00:00:00","2020-10-01T00:00:00","2020-11-01T00:00:00","2020-12-01T00:00:00","2021-01-01T00:00:00","2021-02-01T00:00:00","2021-03-01T00:00:00","2021-04-01T00:00:00","2021-05-01T00:00:00","2021-06-01T00:00:00","2021-07-01T00:00:00","2021-08-01T00:00:00","2021-09-01T00:00:00","2021-10-01T00:00:00","2021-11-01T00:00:00","2021-12-01T00:00:00","2022-01-01T00:00:00","2022-02-01T00:00:00"],"xaxis":"x","y":[0.6798829631339408,0.523068730885601,0.8587457083790934,0.8493467197864828,0.7053005601101563,0.6728873584198408,0.5797278015014958,0.6584107447636038,0.5943689064848886,0.6443685486012625,0.6580816338554303,0.6676551862228929,0.78099005909822,0.6964229331519999,0.7051896047334204,0.7272541509870081,0.8139290983294046,0.9076902193061455,0.7946462886969786,0.9452183143703827,1.1869227546671919,0.9438425019991783,1.244053857448695,1.3020620450582352,1.2975249909066056,1.2161527304245403],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#e ...

# %%
def sum_Cantidad_df(df, n_countries=10):
    df = df.copy()

    df = df.groupby(by=['Pais']).sum().sort_values(by=['Cantidad'], ascending=False)

    top = df[0:n_countries]
    bottom = df[n_countries:].sum()
    bottom.name = 'OTHER'

    top.loc['other'] = bottom

    normalized_sum = df['Cantidad']
    normalized_sum = (normalized_sum-normalized_sum.min())/(normalized_sum.max()-normalized_sum.min())
    
    return top['Cantidad'], df, normalized_sum

top_countries, full_sum, normalized_sum = sum_Cantidad_df(df, n_countries=10)
normalized_sum
# Out:
# C:\Users\Dasa\AppData\Local\Temp\ipykernel_20284\3606482947.py:10: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Pais
# Dominican Rep    1.000000
# Turkey           0.603013
# Mexico           0.343472
# Costa Rica       0.177849
# India            0.163302
#                    ...
# Jamaica          0.000009
# New Zealand      0.000007
# Czechia          0.000004
# Norway           0.000003
# Croatia          0.000000
# Name: Cantidad, Length: 65, dtype: float64

# %%
def get_df_for_top_countries(df, top_countries):
    df = df.copy()
    countries = top_countries.index.values

    df = df[df['Pais'].isin(countries)]
    df = df.dropna()

    return df

df_top = get_df_for_top_countries(df, top_countries)
df_top
# Out:
#            Fecha     Partida  \
# 6417  2020-07-01  7214.20.00
# 6419  2020-09-01  7214.20.00
# 600   2021-10-01  7214.20.00
# 6420  2020-10-01  7214.20.00
# 6421  2020-11-01  7214.20.00
# ...          ...         ...
# 3713  2021-06-01  7318.15.20
# 3847  2021-05-01  7318.15.80
# 4023  2021-01-01  7318.29.00
# 4027  2021-05-01  7318.29.00
# 10887 2020-01-01  7318.15.80
#
#                                              Descripcion           Pais  \
# 6417   Iron/nonalloy steel, concrete reinforcing bars...  Dominican Rep
# 6419   Iron/nonalloy steel, concrete reinforcing bars...  Dominican Rep
# 600    Iron/nonalloy steel, concrete reinforcing bars...         Turkey
# 6420   Iron/nonalloy steel, concrete reinforcing bars...  Dominican Rep
# 6421   Iron/nonalloy steel, concrete reinforcing bars...  Dominican Rep
# ...                                                  ...            ...
# 3713   Iron or steel, bolts and bolts & their nuts or...          Spain
# 3847   Iron or steel, screws and bolts, nesoi, having...          Spain
# 4023   Iron or steel, nonthreaded articles similar to...          Spain
# 4027   Iron or steel, nonthreaded articles similar to...          Spain
# 10887  Iron or steel, screws and bolts, nesoi, having...          Spain
#
#                       Region     Unidad   Cantidad        FOB       Precio  \
# 6417             Gran Caribe  kilograms  8107590.0  3817010.0     0.470795
# 6419             Gran Caribe  kilograms  6878665.0  3130017.0     0.455033
# 600    Europa y Asia central  kilograms  5915815.0  4365484.0     0.737935
# 6420             Gran Caribe  kilograms  5779984.0  2734497.0     0.473098
# 6421             Gran Caribe  kilograms  5707382.0  2861072.0     0.501293
# ...                      ...        ...        ...        ...          ...
# 3713   Europa y Asia central  kilograms        1.0     6320.0  6320.000000
# 3847   Europa y Asia central  kilograms        1.0     3480.0  3480.000000
# 4023   Europa y Asia central  kilograms        1.0     2480.0  2480.000000
# 4027   Europa y Asia central  kilograms        1.0     7096.0  7096.000000
# 10887  Europa y Asia central  kilograms        1.0     4697.0  4697.000000
#
#       HS2   HS4
# 6417   72  7214
# 6419   72  7214
# 600    72  7214
# 6420   72  7214
# 6421   72  7214
# ...    ..   ...
# 3713   73  7318
# 3847   73  7318
# 4023   73  7318
# 4027   73  7318
# 10887  73  7318
#
# [2276 rows x 11 columns]

# %%
def treemap(HS2, df):
    df = df.copy()[df['HS2'] == HS2]
    fig = px.treemap(
        df,
        path=['Region','Pais'],
        values='Cantidad',
        color='Precio',
        # hover_data=['Precio'],
        names = 'Pais',
        # facet_row = 'HS4',
        color_continuous_scale=['green','grey','red'],
        color_continuous_midpoint=np.average(df['Precio'], weights=df['Cantidad']),
        range_color=[0.5,1.5] if HS2==str(72) else [0.8,2.5],
        title=f'Treemap Region-Pais del Volumen de {HS2} exportado y su Precio'
        )
    fig.update_layout(margin = dict(t=50, l=25, r=25, b=25))
    fig.show()

for HS2 in df.HS2.unique():
    treemap(HS2, df)
# Out:
# <div>                            <div id="860a001a-304a-4313-838b-1f7d86e68fc7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("860a001a-304a-4313-838b-1f7d86e68fc7")) {                    Plotly.newPlot(                        "860a001a-304a-4313-838b-1f7d86e68fc7",                        [{"branchvalues":"total","customdata":[[0.6169999382096972],[0.5540422767319516],[1.1622793252255788],[1.3992458872732554],[0.9088518638610317],[0.9742783652472135],[1.0006389490088823],[0.7390354567344068],[0.9736481395807595],[0.597255925160566],[0.927601986630849],[0.7004678406762128],[0.6420085176016864],[4.388389513108614],[1.0323500752795494],[1.0773236350491342],[1.1377420642728033],[1.5067598028287632],[1.1335229283870816],[0.6662541528239203],[
# %%
def group_HS4(df):
    df = df.copy()
    df = df.groupby(by=['HS2','HS4']).sum().reset_index()

    return df
group_HS4(df)
# Out:
#    HS2   HS4     Cantidad         FOB         Precio
# 0   72  7205       2749.0      5227.0       1.901419
# 1   72  7207      41651.0     38888.0       0.933663
# 2   72  7208    5124940.0   4746986.0      62.209996
# 3   72  7209      89754.0     95943.0       7.648478
# 4   72  7210   87185156.0  97218639.0     431.193646
# 5   72  7211     340323.0    359641.0       9.226277
# 6   72  7212    8864962.0   9934432.0     120.202521
# 7   72  7213   15267421.0   9795572.0      24.626150
# 8   72  7214  163438518.0  94948347.0      86.864515
# 9   72  7215      82366.0     83813.0       7.625973
# 10  72  7216    7537324.0   6777691.0     222.911668
# 11  72  7217   16965210.0  18883200.0     381.191554
# 12  72  7219    1415319.0   4174081.0     219.073146
# 13  72  7220       2983.0     16557.0      34.216365
# 14  72  7222      13274.0     45388.0      39.893340
# 15  72  7225      42597.0     80278.0       1.884593
# 16  72  7227     358600.0    280239.0       9.006164
# 17  72  7228     484928.0    213567.0       0.788263
# 18  72  7229      86537.0    122339.0       5.904968
# 19  73  7301     148248.0    314118.0      24.663672
# 20  73  7302      26667.0    105370.0      20.288241
# 21  73  7303       4000.0      6399.0       1.599750
# 22  73  7304     764746.0   1436640.0     916.047333
# 23  73  7306   55494778.0  58185652.0     546.054872
# 24  73  7307     316414.0   1546136.0    7494.797207
# 25  73  7308    9072049.0  21493087.0    2535.054665
# 26  73  7310     336436.0   1715006.0     403.172826
# 27  73  7312     498199.0   1494060.0     753.734299
# 28  73  7313    1093839.0   1780964.0      85.424355
# 29  73  7314    4271947.0   5944946.0     415.130697
# 30  73  7315     185210.0    884276.0    1563.996841
# 31  73  7317    1543207.0   2394490.0    2531.323895
# 32  73  7318    3587889.0  10847433.0  131128.811667
# 33  73  7319       2955.0     17211.0      11.583550
# 34  73  7320      80064.0    358771.0    3526.772788
# 35  73  7323      86198.0    378093.0     130.888598
# 36  73  7325     237568.0    363929.0     324.188113
# 37  73  7326    3767960.0  17796970.0   39453.887671

# %%
def barplot(df):
    fig = None
    fig = px.bar(
        df.sort_values(by=['HS2']),
        x='Fecha',
        y='Cantidad',
        color='Precio',
        facet_col = 'Region',
        # facet_row = 'HS2',
        # facet_row_spacing = 0.01,
        range_color = [0.5,2],
        color_continuous_scale=['green','grey','red'],
        hover_data=['Pais'],
        # name='Pais',
        title='Volumen Exportado por Region y precio (color)',
    )
    fig.update_layout(
        # height = 8000
    )
    fig.show()

def barchart(df):
    for HS2 in df['HS2'].unique():
        df = df.copy()[df['HS2'] == HS2]
        cols = ['Gran Caribe', 'Europa y Asia central','Asia oriental y el Pacifico', 'America Latina'] if HS2 =='72' else df['Region'].unique()
        # range_color=[0.5,1.5] if HS2==str(72) else [0.8,2.5],
        plot_df = df[df['Region'].isin(cols)]
        barplot(plot_df)

barchart(df)
# Out:
# <div>                            <div id="2b10a780-b736-4fac-ad46-2c99b5869a2b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2

# ---> <a href='vscode-notebook-cell:/c%3A/Users/Dasa/Documents/Programacion/Dasa/Data%20Analisis/Explore-Datastudio.ipynb#ch0000007?line=29'>30</a> barchart(df)
#
# c:\Users\Dasa\Documents\Programacion\Dasa\Data Analisis\Explore-Datastudio.ipynb Cell 11' in barchart(df)
#      <a href='vscode-notebook-cell:/c%3A/Users/Dasa/Documents/Programacion/Dasa/Data%20Analisis/Explore-Datastudio.ipynb#ch0000007?line=25'>26</a> # range_color=[0.5,1.5] if HS2==str(72) else [0.8,2.5],
#      <a href='vscode-notebook-cell:/c%3A/Users/Dasa/Documents/Programacion/Dasa/Data%20Analisis/Explore-Datastudio.ipynb#ch0000007?line=26'>27</a> plot_df = df[df['Region'].isin(cols)]
# ---> <a href='vscode-notebook-cell:/c%3A/Users/Dasa/Documents/Programacion/Dasa/Data%20Analisis/Explore-Datastudio.ipynb#ch0000007?line=27'>28</a> barplot(plot_df)
#
# c:\Users\Dasa\Documents\Programacion\Dasa\Data Analisis\Explore-Datastudio.ipynb Cell 11' in barplot(df)
#       <a href='vscode-notebook-cell:/c%3A/Users/Dasa/Documents/Programacion/Dasa/Data%20Analisis/Explore-Datastudio.ipynb#ch0000007?line=0'>1</a> def barplot(df):
#       <a href='vscode-notebook-cell:/c%3A/Users/Dasa/Documents/Programacion/Dasa/Data%20Analisis/Explore-Datastudio.ipynb#ch0000007?line=1'>2</a>     fig = None
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Dasa/Documents/Programacion/Dasa/Data%20Analisis/Explore-Datastudio.ipynb#ch0000007?line=2'>3</a>     fig = px.bar(
#       <a href='vscode-notebook-cell:/c%3A/Users/Dasa/Documents/Programacion/Dasa/Data%20Analisis/Explore-Datastudio.ipynb#ch0000007?line=3'>4</a>         df.sort_values(by=['HS2']),
#       <a href='vscode-notebook-cell:/c%3A/Users/Dasa/Documents/Programacion/Dasa/Data%20Analisis/Explore-Datastudio.ipynb#ch0000007?line=4'>5</a>         x='Fecha',
#       <a href='vscode-notebook-cell:/c%3A/Users/Dasa/Documents/Programacion/Dasa/Data%20Analisis/Explore-Datastudio.ipynb#ch0000007?line=5'>6</a>         y='Cantidad',
#       <a href='vscode-notebook-cell:/c%3A/Users/Dasa/Documents/Programacion/Dasa/Data%20Analisis/Explore-Datastudio.ipynb#ch0000007?line=6'>7</a>         color='Precio',
#       <a href='vscode-notebook-cell:/c%3A/Users/Dasa/Documents/Programacion/Dasa/Data%20Analisis/Explore-Datastudio.ipynb#ch0000007?line=7'>8</a>         facet_col = 'Region',
#       <a href='vscode-notebook-cell:/c%3A/Users/Dasa/Documents/Programacion/Dasa/Data%20Analisis/Explore-Datastudio.ipynb#ch0000007?line=8'>9</a>         # facet_row = 'HS2',
#      <a href='vscode-notebook-cell:/c%3A/Users/Dasa/Documents/Programacion/Dasa/Data%20Analisis/Explore-Datastudio.ipynb#ch0000007?line=9'>10</a>         # facet_row_spacing = 0.01,
#      <a href='vscode-notebook-cell:/c%3A/Users/Dasa/Documents/Programacion/Dasa/Data%20Analisis/Explore-Datastudio.ipynb#ch0000007?line=10'>11</a>         range_color = [0.5,2],
#      <a href='vscode-notebook-cell:/c%3A/Users/Dasa/Documents/Programacion/Dasa/Data%20Analisis/Explore-Datastudio.ipynb#ch0000007?line=11'>12</a>         color_continuous_scale=['green','grey','red'],
#      <a href='vscode-notebook-cell:/c%3A/Users/Dasa/Documents/Programacion/Dasa/Data%20Analisis/Explore-Datastudio.ipynb#ch0000007?line=12'>13</a>         hover_data=['Pais'],
#      <a href='vscode-notebook-cell:/c%3A/Users/Dasa/Documents/Programacion/Dasa/Data%20Analisis/Explore-Datastudio.ipynb#ch0000007?line=13'>14</a>         # name='Pais',
#      <a href='vscode-notebook-cell:/c%3A/Users/Dasa/Documents/Programacion/Dasa/Data%20Analisis/Explore-Datastudio.ipynb#ch0000007?line=14'>15</a>         title='Volumen Exportado por Region y precio (color)',
#      <a href='vscode-notebook-cell:/c%3A/Users/Dasa/Documents/Programacion/Dasa/Data%20Analisis/Explore-Datastudio.ipynb#ch0000007?line=15'>16</a>     )
#      <a href='vscode-notebook-cell:/c%3A/Users/Dasa/Documents/Programacion/Dasa/Data%20Analisis/Explore-Datastudio.ipynb#ch0000007?line=16'>17</a>     fig.update_layout(
#      <a href='vscode-notebook-cell:/c%3A/Users/Dasa/Documents/Programacion/Dasa/Data%20Analisis/Explore-Datastudio.ipynb#ch0000007?line=17'>18</a>         # height = 8000
#      <a href='vscode-notebook-cell:/c%3A/Users/Dasa/Documents/Programacion/Dasa/Data%20Analisis/Explore-Datastudio.ipynb#ch0000007?line=18'>19</a>     )
#      <a href='vscode-notebook-cell:/c%3A/Users/Dasa/Documents/Programacion/Dasa/Data%20Analisis/Explore-Datastudio.ipynb#ch0000007?line=19'>20</a>     fig.show()
#
# File c:\Users\Dasa\Documents\Programacion\Dasa\Data Analisis\venv\lib\site-packages\plotly\express\_chart_types.py:373, in bar(data_frame, x, y, color, pattern_shape, facet_row, facet_col, facet_col_wrap, facet_row_spacing, facet_col_spacing, hover_name, hover_data, custom_data, text, base, error_x, error_x_minus, error_y, error_y_minus, animation_frame, animation_group, category_orders, labels, color_discrete_sequence, color_discrete_map, color_continuous_scale, pattern_shape_sequence, pattern_shape_map, range_color, color_continuous_midpoint, opacity, orientation, barmode, log_x, log_y, range_x, range_y, text_auto, title, template, width, height)
#     <a href='file:///c%3A/Users/Dasa/Documents/Programacion/Dasa/Data%20Analisis/venv/lib/site-packages/plotly/express/_chart_types.py?line=324'>325</a> def bar(
#     <a href='file:///c%3A/Users/Dasa/Documents/Programacion/Dasa/Data%20Analisis/venv/lib/site-packages/plotly/express/_chart_types.py?line=325'>326</a>     data_frame=None,
#     <a href='file:///c%3A/Users/Dasa/Documents/Programacion/Dasa/Data%20Analisis/venv/lib/site-packages/plotly/express/_chart_types.py?line=326'>327</a>     x=None,
#    (...)
#     <a href='file:///c%3A/Users/Dasa/Documents/Programacion/Dasa/Data%20Analisis/venv/lib/site-packages/plotly/express/_chart_types.py?line=366'>367</a>     height=None,
#     <a href='file:///c%3A/Users/Dasa/Documents/Programacion/Dasa/Data%20Analisis/venv/lib/site-packages/plotly/express/_chart_types.py?line=367'>368</a> ) -> go.Figure:
#     <a href='file:///c%3A/Users/Dasa/Documents/Programacion/Dasa/Data%20Analisis/venv/lib/site-packages/plotly/express/_chart_types.py?line=368'>369</a>     """
#     <a href='file:///c%3A/Users/Dasa/Documents/Programacion/Dasa/Data%20Analisis/venv/lib/site-packages/plotly/express/_chart_types.py?line=369'>370</a>     In a bar plot, each row of `data_frame` is represented as a rectangular
#     <a href='file:///c%3A/Users/Dasa/Documents/Programacion/Dasa/Data%20Analisis/venv/lib/site-packages/plotly/express/_chart_types.py?line=370'>371</a>     mark.
#     <a href='file:///c%3A/Users/Dasa/Documents/Programacion/Dasa/Data%20Analisis/venv/lib/site-packages/plotly/express/_chart_types.py?line=371'>372</a>     """
# --> <a href='file:///c%3A/Users/Dasa/Documents/Programacion/Dasa/Data%20Analisis/venv/lib/site-packages/plotly/express/_chart_types.py?line=372'>373</a>     return make_figure(
#     <a href='file:///c%3A/Users/Dasa/Documents/Programacion/Dasa/Data%20Analisis/venv/lib/site-packages/plotly/express/_chart_types.py?line=373'>374</a>         args=locals(),
#     <a href='file:///c%3A/Users/Dasa/Documents/Programacion/Dasa/Data%20Analisis/venv/lib/site-packages/plotly/express/_chart_types.py?line=374'>375</a>         constructor=go.Bar,
#     <a href='file:///c%3A/Users/Dasa/Documents/Programacion/Dasa/Data%20Analisis/venv/lib/site-packages/plotly/express/_chart_types.py?line=375'>376</a>         trace_patch=dict(textposition="auto"),
#     <a href='file:///c%3A/Users/Dasa/Documents/Programacion/Dasa/Data%20Analisis/venv/lib/site-packages/plotly/express/_chart_types.py?line=376'>377</a>         layout_patch=dict(barmode=barmode),
#     <a href='file:///c%3A/Users/Dasa/Documents/Programacion/Dasa/Data%20Analisis/venv/lib/site-packages/plotly/express/_chart_types.py?line=377'>378</a>     )
#
# File c:\Users\Dasa\Documents\Programacion\Dasa\Data Analisis\venv\lib\site-packages\plotly\express\_core.py:2185, in make_figure(args, constructor, trace_patch, layout_patch)
#    <a href='file:///c%3A/Users/Dasa/Documents/Programacion/Dasa/Data%20Analisis/venv/lib/site-packages/plotly/express/_core.py?line=2181'>2182</a> if args.get("marginal_y") is not None:
#    <a href='file:///c%3A/Users/Dasa/Documents/Programacion/Dasa/Data%20Analisis/venv/lib/site-packages/plotly/express/_core.py?line=2182'>2183</a>     ncols += 1
# -> <a href='file:///c%3A/Users/Dasa/Documents/Programacion/Dasa/Data%20Analisis/venv/lib/site-packages/plotly/express/_core.py?line=2184'>2185</a> fig = init_figure(
#    <a href='file:///c%3A/Users/Dasa/Documents/Programacion/Dasa/Data%20Analisis/venv/lib/site-packages/plotly/express/_core.py?line=2185'>2186</a>     args, subplot_type, frame_list, nrows, ncols, col_labels, row_labels
#    <a href='file:///c%3A/Users/Dasa/Documents/Programacion/Dasa/Data%20Analisis/venv/lib/site-packages/plotly/express/_core.py?line=2186'>2187</a> )
#    <a href='file:///c%3A/Users/Dasa/Documents/Programacion/Dasa/Data%20Analisis/venv/lib/site-packages/plotly/express/_core.py?line=2188'>2189</a> # Position traces in subplots
#    <a href='file:///c%3A/Users/Dasa/Documents/Programacion/Dasa/Data%20Analisis/venv/lib/site-packages/plotly/express/_core.py?line=2189'>2190</a> for frame in frame_list:
#
# File c:\Users\Dasa\Documents\Programacion\Dasa\Data Analisis\venv\lib\site-packages\plotly\express\_core.py:2330, in init_figure(args, subplot_type, frame_list, nrows, ncols, col_labels, row_labels)
#    <a href='file:///c%3A/Users/Dasa/Documents/Programacion/Dasa/Data%20Analisis/venv/lib/site-packages/plotly/express/_core.py?line=2326'>2327</a>     _spacing_error_translator(e, "Vertical", "facet_row_spacing")
#    <a href='file:///c%3A/Users/Dasa/Documents/Programacion/Dasa/Data%20Analisis/venv/lib/site-packages/plotly/express/_core.py?line=2328'>2329</a> # Remove explicit font size of row/col titles so template can take over
# -> <a href='file:///c%3A/Users/Dasa/Documents/Programacion/Dasa/Data%20Analisis/venv/lib/site-packages/plotly/express/_core.py?line=2329'>2330</a> for annot in fig.layout.annotations:
#    <a href='file:///c%3A/Users/Dasa/Documents/Programacion/Dasa/Data%20Analisis/venv/lib/site-packages/plotly/express/_core.py?line=2330'>2331</a>     annot.update(font=None)
#    <a href='file:///c%3A/Users/Dasa/Documents/Programacion/Dasa/Data%20Analisis/venv/lib/site-packages/plotly/express/_core.py?line=2332'>2333</a> return fig
#
# UnboundLocalError: local variable 'fig' referenced before assignment

# %%
# Create figure with secondary y-axis
fig = make_subplots(specs=[[{"secondary_y": True}]])

# Add traces
for pais in df['Pais'].unique():
    pais_df = df[df.Pais == pais].sort_values(by=['Fecha'])
    fig.add_trace(
        go.Bar(
            x=pais_df.Fecha,
            y=pais_df.Kg,
            name=pais,
            # mode='lines',
            ),
        secondary_y=False,
    )

fig.add_trace(
    go.Scatter(x=avg_df.index, y=avg_df['Precio'], name="Precio Promedio Global"),
    secondary_y=True,
)

# Add figure title
fig.update_layout(
    title_text="Double Y Axis Example"
)

# Set x-axis title
fig.update_xaxes(title_text="xaxis title")

# Set y-axes titles
fig.update_yaxes(title_text="<b>primary</b> yaxis title", secondary_y=False)
fig.update_yaxes(title_text="<b>secondary</b> yaxis title", secondary_y=True)

fig.show()
# Out:
# <div>                            <div id="5dae991c-3dd3-4014-a289-0a46582ce401" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5dae991c-3dd3-4014-a289-0a46582ce401")) {                    Plotly.newPlot(                        "5dae991c-3dd3-4014-a289-0a46582ce401",                        [{"name":"Philippines","x":["2020-12-01T00:00:00","2021-01-01T00:00:00","2021-02-01T00:00:00","2021-03-01T00:00:00","2021-04-01T00:00:00","2021-05-01T00:00:00","2021-06-01T00:00:00","2021-07-01T00:00:00","2021-08-01T00:00:00","2021-09-01T00:00:00","2021-10-01T00:00:00","2021-11-01T00:00:00"],"y":[150900.0,104976.0,4698.0,74696.0,15040.0,561236.0,271066.0,141918.0,491297.0,446619.0,65390.0,28610.0],"type":"bar","xaxis":"x","yaxis":"y"},{"name":"Viet Nam","x":["2020-12-01T00:00:00","2021-01-01T00:00:00","2021-02-01T00:00:00","2021-03-01T00:00:00","2021-04-01T00:00:00","2021-05-01T00:00:00","2021-06-01T00:00:00","2021-07-01T00:00:00","2021-08-01T00:00:00","2021-09-01T00:00:00","2021-10-01T00:00:00","2021-11-01T00:00:00"],"y":[181700.0,342663.0,97469.0,393785.0,283777.0,295300.0,253529.0,429386.0,272958.0,494250.0,354004.0,507178.0],"type":"bar","xaxis":"x","yaxis":"y"},{"name":"Mexico","x":["2020-12-01T00:00:00","2021-01-01T00:00:00","2021-02-01T00:00:00","2021-03-01T00:00:00","2021-04-01T00:00:00","2021-05-01T00:00:00","2021-06-01T00:00:00","2021-07-01T00:00:00","2021-08-01T00:00:00","2021-09-01T00:00:00","2021-10-01T00:00:00","2021-11-01T00:00:00"],"y":[157780.0,216624.0,225989.0,157600.0,126235.0,120307.0,294743.0,216745.0,187965.0,222481.0,62698.0,444026.0],"type":"bar","xaxis":"x","yaxis":"y"},{"name":"Chile","x":["2021-01-01T00:00:00","2021-02-01T00:00:00","2021-04-01T00:00:00","2021-06-01T00:00:00","2021-07-01T00:00:00","2021-09-01T00:00:00","2021-10-01T00:00:00","2021-11-01T00:00:00"],"y":[345447.0,238389.0,236866.0,131368.0,34113.0,324985.0,49122.0,99415.0],"type":"bar","xaxis":"x","yaxis":"y"},{"name":"Rwanda","x":["2021-09-01T00:00:00"],"y":[315450.0],"type":"bar","xaxis":"x","yaxis":"y"},{"name":"Thailand","x":["2020-12-01T00:00:00","2021-01-01T00:00:00","2021-02-01T00:00:00","2021-03-01T00:00:00","2021-04-01T00:00:00","2021-05-01T00:00:00","2021-06-01T00:00:00","2021-07-01T00:00:00","2021-08-01T00:00:00","2021-09-01T00:00:00","2021-10-01T00:00:00","2021-11-01T00:00:00"],"y":[29760.0,55378.0,2006.0,232455.0,2981.0,125879.0,28716.0,75553.0,298964.0,138728.0,30524.0,53905.0],"type":"bar","xaxis":"x","yaxis":"y"},{"name":"Bangladesh","x":["2020-12-01T00:00:00","2021-01-01T00:00:00","2021-02-01T00:00:00","2021-03-01T00:00:00","2021-04-01T00:00:00","2021-06-01T00:00:00","2021-07-01T00:00:00","2021-09-01T00:00:00","2021-11-01T00:00:00"],"y":[4694.0,31868.0,37305.0,21460.0,49623.0,51603.0,108003.0,236623.0,182566.0],"type":"bar","xaxis":"x","yaxis":"y"},{"name":"Nigeria","x":["2021-01-01T00:00:00","2021-02-01T00:00:00","2021-04-01T00:00:00","2021-05-01T00:00:00","2021-06-01T00:00:00","2021-07-01T00:00:00","2021-08-01T00:00:00","2021-09-01T00:00:00","2021-11-01T00:00:00"],"y":[215080.0,164520.0,46373.0,122186.0,98265.0,20000.0,16700.0,27687.0,22000.0],"type":"bar","xaxis":"x","yaxis":"y"},{"name":"Saudi Arabia","x":["2020-12-01T00:00:00","2021-01-01T00:00:00","2021-03-01T00:00:00","2021-04-01T00:00:00","2021-05-01T00:00:00","2021-06-01T00:00:00","2021-07-01T00:00:00","2021-08-01T00:00:00","2021-09-01T00:00:00","2021-10-01T00:00:00","2021-11-01T00:00:00"],"y":[209258.0,78386.0,130000.0,115810.0,52474.0,108761.0,182287.0,104000.0,52000.0,104000.0,79000.0],"type":"bar","xaxis":"x","yaxis":"y"},{"name":"Ghana","x":["2021-01-01T00:00:00","2021-04-01T00:00:00","2021-05-01T00:00:00","2021-06-01T00:00:00","2021-08-01T00:00:00","2021-09-01T00:00:00","2021-10-01T00:00:00","2021-11-01T00:00:00"],"y":[15270.0,4230.0,1 ...

# %%
normalized_full = full['Kg']
# normalized_full=(normalized_full-normalized_full.mean())/normalized_full.std()
normalized_full = (normalized_full-normalized_full.min())/(normalized_full.max()-normalized_full.min())
normalized_full
# Out:
# Pais
# Viet Nam                            1.000000
# Mexico                              0.622932
# Philippines                         0.603283
# Chile                               0.373700
# Saudi Arabia                        0.311300
#                                       ...
# Madagascar                          0.000429
# Lao People's Democratic Republic    0.000403
# Bulgaria                            0.000246
# Vanuatu                             0.000152
# Dominican Republic                  0.000000
# Name: Kg, Length: 88, dtype: float64

# %%
fig = px.line(
    df,
    x = df.Fecha,
    y = 'Precio',
    color = 'Pais',
    # opacity = normalized_full
)

fig.show()
# Out:
# <div>                            <div id="80968b0e-d7ce-4312-a815-9acccd01334b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("80968b0e-d7ce-4312-a815-9acccd01334b")) {                    Plotly.newPlot(                        "80968b0e-d7ce-4312-a815-9acccd01334b",                        [{"hovertemplate":"Pais=Philippines<br>Fecha=%{x}<br>Precio=%{y}<extra></extra>","legendgroup":"Philippines","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Philippines","orientation":"v","showlegend":true,"x":["2021-05-01T00:00:00","2021-08-01T00:00:00","2021-09-01T00:00:00","2021-06-01T00:00:00","2020-12-01T00:00:00","2021-07-01T00:00:00","2021-01-01T00:00:00","2021-03-01T00:00:00","2021-10-01T00:00:00","2021-11-01T00:00:00","2021-04-01T00:00:00","2021-02-01T00:00:00"],"xaxis":"x","y":[5.4,7.14,7.01,5.98,3.72,4.37,2.05,5.64,2.03,10.49,1.46,13.62],"yaxis":"y","type":"scatter"},{"hovertemplate":"Pais=Viet Nam<br>Fecha=%{x}<br>Precio=%{y}<extra></extra>","legendgroup":"Viet Nam","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Viet Nam","orientation":"v","showlegend":true,"x":["2021-11-01T00:00:00","2021-09-01T00:00:00","2021-07-01T00:00:00","2021-03-01T00:00:00","2021-10-01T00:00:00","2021-01-01T00:00:00","2021-05-01T00:00:00","2021-04-01T00:00:00","2021-08-01T00:00:00","2021-06-01T00:00:00","2020-12-01T00:00:00","2021-02-01T00:00:00"],"xaxis":"x","y":[5.53,5.5,4.05,1.66,7.03,1.19,2.56,1.86,4.2,2.22,1.92,0.96],"yaxis":"y","type":"scatter"},{"hovertemplate":"Pais=Mexico<br>Fecha=%{x}<br>Precio=%{y}<extra></extra>","legendgroup":"Mexico","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Mexico","orientation":"v","showlegend":true,"x":["2021-11-01T00:00:00","2021-06-01T00:00:00","2021-02-01T00:00:00","2021-09-01T00:00:00","2021-07-01T00:00:00","2021-01-01T00:00:00","2021-08-01T00:00:00","2020-12-01T00:00:00","2021-03-01T00:00:00","2021-04-01T00:00:00","2021-05-01T00:00:00","2021-10-01T00:00:00"],"xaxis":"x","y":[1.16,1.52,1.34,1.65,1.51,1.26,1.62,1.27,1.37,1.39,1.53,1.48],"yaxis":"y","type":"scatter"},{"hovertemplate":"Pais=Chile<br>Fecha=%{x}<br>Precio=%{y}<extra></extra>","legendgroup":"Chile","line":{"color":"#ab63fa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Chile","orientation":"v","showlegend":true,"x":["2021-01-01T00:00:00","2021-09-01T00:00:00","2021-02-01T00:00:00","2021-04-01T00:00:00","2021-06-01T00:00:00","2021-11-01T00:00:00","2021-10-01T00:00:00","2021-07-01T00:00:00"],"xaxis":"x","y":[0.91,1.19,0.92,1.19,1.18,1.4,1.1,1.2],"yaxis":"y","type":"scatter"},{"hovertemplate":"Pais=Rwanda<br>Fecha=%{x}<br>Precio=%{y}<extra></extra>","legendgroup":"Rwanda","line":{"color":"#FFA15A","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Rwanda","orientation":"v","showlegend":true,"x":["2021-09-01T00:00:00"],"xaxis":"x","y":[0.89],"yaxis":"y","type":"scatter"},{"hovertemplate":"Pais=Thailand<br>Fecha=%{x}<br>Precio=%{y}<extra></extra>","legendgroup":"Thailand","line":{"color":"#19d3f3","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Thailand","orientation":"v","showlegend":true,"x":["2021-08-01T00:00:00","2021-03-01T00:00:00","2021-09-01T00:00:00","2021-05-01T00:00:00","2021-07-01T00:00:00","2021-01-01T00:00:00","2021-11-01T00:00:00","2021-10-01T00:00:00","2020-12-01T00:00:00","2021-06-01T00:00:00","2021-04-01T00:00:00","2021-02-01T00:00:00"],"xaxis":"x","y":[2.36,0.82,1.1,2.11,1.99,1.32,3.38,1.51,1.71,0.98,2.35,2.49],"yaxis":"y","type":"scatter"},{"hovertemplate":"Pais=Bangladesh<br>Fecha=%{x}<br>Precio=%{y}<extra></extra>","legendgroup":"Bangladesh","line":{"color":"#FF6692","dash":"solid"},"marker":{"symbol":"cir ...

# %%
df.Fecha.unique()
# Out:
# array(['2021-05-01T00:00:00.000000000', '2021-11-01T00:00:00.000000000',
#        '2021-09-01T00:00:00.000000000', '2021-08-01T00:00:00.000000000',
#        '2021-07-01T00:00:00.000000000', '2021-03-01T00:00:00.000000000',
#        '2021-10-01T00:00:00.000000000', '2021-01-01T00:00:00.000000000',
#        '2021-06-01T00:00:00.000000000', '2021-04-01T00:00:00.000000000',
#        '2021-02-01T00:00:00.000000000', '2020-12-01T00:00:00.000000000'],
#       dtype='datetime64[ns]')

# %%
avg_df = pd.DataFrame(columns=['Precio'])

for month in df.Fecha.unique():
    temp_df = df.copy()[df['Fecha'] == month]
    avg = np.average(temp_df.Precio, weights=temp_df.Kg)
    # print(avg)
    avg_df.loc[month] = avg
    avg_df = avg_df.sort_index()

avg_df
# Out:
#               Precio
# 2020-12-01  2.485628
# 2021-01-01  1.121008
# 2021-02-01  1.992638
# 2021-03-01  2.121146
# 2021-04-01  1.972524
# 2021-05-01  3.142066
# 2021-06-01  2.982081
# 2021-07-01  2.727451
# 2021-08-01  3.556833
# 2021-09-01  3.764178
# 2021-10-01  4.092415
# 2021-11-01  3.026170

# %%
fig = go.Figure()

# Add scatter trace with medium sized markers
fig.add_trace(
    go.Scatter(
        mode='markers',
        x=x,
        y=y,
        marker=dict(
            color='LightSkyBlue',
            size=20,
            line=dict(
                color='MediumPurple',
                width=2
            )
        ),
        showlegend=False
    )
)

# Add trace with large marker
fig.add_trace(
    go.Scatter(
        mode='markers',
        x=[2],
        y=[4.5],
        marker=dict(
            color='LightSkyBlue',
            size=120,
            line=dict(
                color='MediumPurple',
                width=12
            )
        ),
        showlegend=False
    )
)

fig.show()
